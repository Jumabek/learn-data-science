# %%
import catboost as cb
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

import optuna

# %%
def objective(trial):
    data, target = load_breast_cancer(return_X_y=True)
    train_x, valid_x, train_y, valid_y = train_test_split(data, target, test_size=0.3)

    param = {
        "objective": trial.suggest_categorical("objective", ["Logloss", "CrossEntropy"]),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.1),
        "depth": trial.suggest_int("depth", 1, 12),
        "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
        "bootstrap_type": trial.suggest_categorical(
            "bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]
        ),
        "used_ram_limit": "3gb",
    }

    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1)

    gbm = cb.CatBoostClassifier(**param)

    gbm.fit(train_x, train_y, eval_set=[(valid_x, valid_y)], verbose=0, early_stopping_rounds=100)

    preds = gbm.predict(valid_x)
    pred_labels = np.rint(preds)
    accuracy = accuracy_score(valid_y, pred_labels)
    return accuracy

# %%
    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=100, timeout=600)

    print("Number of finished trials: {}".format(len(study.trials)))

    print("Best trial:")
    trial = study.best_trial

    print("  Value: {}".format(trial.value))

    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))
# Out:
# [I 2021-05-16 12:01:12,253] A new study created in memory with name: no-name-0447d5d4-1205-4a17-93de-be9dc3fb34e5
# [I 2021-05-16 12:01:23,820] Trial 0 finished with value: 0.9590643274853801 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.09930166116574451, 'depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.24828896022205982}. Best is trial 0 with value: 0.9590643274853801.
# [I 2021-05-16 12:01:24,360] Trial 1 finished with value: 0.9824561403508771 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05820031109628691, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 1 with value: 0.9824561403508771.
# [I 2021-05-16 12:01:28,616] Trial 2 finished with value: 0.9649122807017544 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.08728164755911122, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.8755230026509923}. Best is trial 1 with value: 0.9824561403508771.
# [I 2021-05-16 12:01:29,472] Trial 3 finished with value: 0.9649122807017544 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.08199193366274743, 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.055362999581459}. Best is trial 1 with value: 0.9824561403508771.
# [I 2021-05-16 12:01:29,966] Trial 4 finished with value: 0.9766081871345029 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.09349251111927565, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.7936780847817765}. Best is trial 1 with value: 0.9824561403508771.
# [I 2021-05-16 12:01:30,386] Trial 5 finished with value: 0.9532163742690059 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.012436958356741808, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.8451683410640788}. Best is trial 1 with value: 0.9824561403508771.
# [I 2021-05-16 12:01:30,681] Trial 6 finished with value: 0.9532163742690059 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.010799866786762504, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.14780249910514492}. Best is trial 1 with value: 0.9824561403508771.
# [I 2021-05-16 12:01:31,714] Trial 7 finished with value: 0.9473684210526315 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05024715278889428, 'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.5493287082817506}. Best is trial 1 with value: 0.9824561403508771.
# [I 2021-05-16 12:01:32,243] Trial 8 finished with value: 0.9883040935672515 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09607767508949795, 'depth': 1, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.
 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:02:58,097] Trial 76 finished with value: 0.9707602339181286 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.07926924004006665, 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 8.587316463541583}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:02:58,624] Trial 77 finished with value: 0.9649122807017544 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.08921802232860652, 'depth': 1, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:02:58,955] Trial 78 finished with value: 0.9649122807017544 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.04604542913527543, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.6540908462024594}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:03:03,645] Trial 79 finished with value: 0.9766081871345029 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.07317511327883341, 'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.243948839239573}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:03:04,314] Trial 80 finished with value: 0.9707602339181286 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.052044347772298195, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 9.355318509252244}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:03:04,863] Trial 81 finished with value: 0.9766081871345029 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.07148828877623069, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 8.592382291262552}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:03:05,472] Trial 82 finished with value: 0.9707602339181286 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.06096036238120871, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.432316288441001}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:03:05,850] Trial 83 finished with value: 0.9649122807017544 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.08193699702817656, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.881484171596062}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:03:06,432] Trial 84 finished with value: 0.9824561403508771 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.06469181445081774, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.548440012874674}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:03:06,857] Trial 85 finished with value: 0.9766081871345029 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05706247935181674, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:03:07,258] Trial 86 finished with value: 0.9707602339181286 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.06853616879946509, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.857744387104868}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:03:08,351] Trial 87 finished with value: 0.9766081871345029 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.08793925751522944, 'depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:03:08,800] Trial 88 finished with value: 0.9766081871345029 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.08438243976466481, 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.5946687031187}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:03:09,081] Trial 89 finished with value: 0.9766081871345029 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.0929745835865331, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9373578623947155}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:03:09,515] Trial 90 finished with value: 0.9590643274853801 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.04000752142331337, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 8.218974002542671}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:03:10,019] Trial 91 finished with value: 0.9824561403508771 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.0653224474462534, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.651357520799647}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:03:10,480] Trial 92 finished with value: 0.9649122807017544 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.06293976943653588, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.5196281697209892}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:03:11,127] Trial 93 finished with value: 0.9883040935672515 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.07596236338394181, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.11988900432605507}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:03:11,866] Trial 94 finished with value: 0.9649122807017544 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.07532781221176221, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.15251754171495038}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:03:12,222] Trial 95 finished with value: 0.9649122807017544 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.0765630850751144, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.4859314939900562}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:03:13,260] Trial 96 finished with value: 0.9824561403508771 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.07870375659624748, 'depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.2825450806239188}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:03:13,740] Trial 97 finished with value: 0.9590643274853801 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09652597319728759, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.7101201657680406}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:03:14,081] Trial 98 finished with value: 0.9532163742690059 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.07072429793460196, 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.6017849070352805}. Best is trial 46 with value: 1.0.
# [I 2021-05-16 12:03:14,687] Trial 99 finished with value: 0.9766081871345029 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.04289720639971754, 'depth': 2, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 46 with value: 1.0.
# Number of finished trials: 100
# Best trial:
#   Value: 1.0
#   Params:
#     objective: Logloss
#     colsample_bylevel: 0.08591610256307494
#     depth: 4
#     boosting_type: Plain
#     bootstrap_type: Bayesian
#     bagging_temperature: 8.018830019177148
